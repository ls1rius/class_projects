# %%
import math
import pandas as pd
import numpy as np
from pylab import *
import random
mpl.rcParams['font.sans-serif'] = ['SimHei']  # 添加这条可以让图形显示中文

# %%
# 2变换法
def TSP_2_reverse(df,i,j):
    df = df.copy()
    for idx in range(i,int((j-i+1)/2)+i):
        df_tmp = df.loc[idx]
        df.loc[idx] = df.loc[j-(idx-i)]
        df.loc[j-(idx-i)] = df_tmp
    return df

# %%
# 获取点对点的距离
def get_2p_dis(df,i,j):
    return math.sqrt( (df["lo"].loc[i]-df["lo"].loc[j])**2 + (df["la"].loc[i]-df["la"].loc[j])**2 )

# %%
# 获取总的路径花费
def get_total_cost(df,df_city_map):
    res = 0
    for i in range(len(df) -1):
        res += df_city_map[df["city"].loc[i]][df["city"].loc[i+1]]
    res += df_city_map[df["city"].loc[len(df)-1]][df["city"].loc[0]]
    return res

# %%
# 获取总的路径花费
def get_total_list_cost(city_list,df_city_map):
    res = 0
    for i in range(len(df) -1):
        res += df_city_map[city_list[i]][city_list[i+1]]
    res += df_city_map[city_list[len(df)-1]][city_list[0]]
    return res

# %%
# 预处理城市之间两两距离
def pre_deal(df):
    df_len = len(df)
    city_map_dict = {}
    for i in range(df_len):
        city_mul = {}
        for j in range(df_len):
            city_mul[df.loc[j]["city"]] = get_2p_dis(df,i,j)
        city_map_dict[df.loc[i]["city"]] = city_mul
    return pd.DataFrame.from_dict(city_map_dict)

# %%
# 数据读入
def read_data():
    df = pd.DataFrame(columns = ["city", "lo", "la"]) #创建一个空的dataframe
    with open("TSP.txt","r",encoding="utf-8") as f:
        for line in f.readlines():
            city,lo,la = line.replace("\n","").split(" ")
    #         print(city,lo,la)
            df = df.append({"city":city,"lo":float(lo),"la":float(la)},ignore_index=True)
    return df

# %%
# 画图
def plot_city_route(df):
    plt.clf()
    # plot中参数的含义分别是横轴值，纵轴值，线的形状，颜色，透明度,线的宽度和标签
    plt.plot(df["lo"], df["la"], 'ro-', color='#FF0000', alpha=0.8, linewidth=1, label='city')
    plt.legend(loc="lower left")
    plt.xlabel('经度')
    plt.ylabel('纬度')

# %%
def lower_bound(nums, target):
    low, high = 0, len(nums)-1
    pos = len(nums)
    while low<high:
        mid = int((low+high)/2)
        if nums[mid] < target:
            low = mid+1
        else:#>=
            high = mid
            #pos = high
    if nums[low]>=target:
        pos = low
    return pos

# %%
# 双链杂交
def hybrid_route(ra, rb, p_cro):
    
    # 随机确定杂交起始位置
    cro_pos = random.randint(0,len(ra)-1)
    
    for cur_pos in range(cro_pos,len(ra)):
        # 杂交概率
        if(random.random()<=p_cro):
            city_a = ra[cur_pos]
            city_b = rb[cur_pos] 
            if(city_a == city_b):
                continue
            
            # city a 在 list b 中的位置
            b_city_a_pos = rb.index(city_a)
            # city b 在 list a 中的位置
            a_city_b_pos = ra.index(city_b)   
            
            # 交换城市
            tmp_city = rb[cur_pos]
            rb[cur_pos] = ra[cur_pos]
            ra[cur_pos] = tmp_city
            
            # 防止重复，相应城市也要交换
            tmp_city = rb[b_city_a_pos]
            rb[b_city_a_pos] = ra[a_city_b_pos]
            ra[a_city_b_pos] = tmp_city
            
        else:
            continue

# %%
# 变异
def mut_route(route, p_mut):
    for i in range(len(route)):
        if(random.random()<=p_mut):
            change_pos = random.randint(0, len(route)-1)
            if i == change_pos:
                continue
            else:
                # 变异，即随机与另一个城市交换位置
                tmp_city = route[change_pos]
                route[change_pos] = route[i]
                route[i] = tmp_city

# %%
if __name__ == "__main__":
    N = 200
    M = 200
    p_cro = 0.8
    p_mut = 0.1

    # 数据读入，数据预处理
    df = read_data()
    df_city_map = pre_deal(df)
    df_cur = df
    # 去重set
    df_city_group = set()
    while len(df_city_group)<N:
        u = random.randint(0,len(df_cur)-1-1)
        v = random.randint(u+1,len(df_cur)-1)
        # 逆序uv路径
        df_cur = TSP_2_reverse(df_cur,u,v)
        # 生成初始种群
        df_city_group.add(tuple(list(df_cur["city"])))

    # plot_city_route(df_cur)

# %%
    # 初代数据预处理
    df_city_group_cost_dict = pd.DataFrame(columns = ["route", "cost", "p_sel"])
    for item in df_city_group:
        cur_city_list_cost = get_total_list_cost(list(item),df_city_map)
        df_city_group_cost_dict = df_city_group_cost_dict.append({"route":item,
                                                                  "cost":cur_city_list_cost,
                                                                  "p_sel":1.0/cur_city_list_cost},
                                                                 ignore_index=True)

# %%
    loss_str_output = ""
    for epoch in range(200000):
    # 轮盘概率预处理
        p_sel_sum = [0 for _ in range(len(df_city_group_cost_dict))]
        for i in range(len(df_city_group_cost_dict)):
            if(i==0):
                p_sel_sum[i] = df_city_group_cost_dict.iloc[i]["p_sel"]
            else:
                p_sel_sum[i] = p_sel_sum[i-1] + df_city_group_cost_dict.iloc[i]["p_sel"]

        total_p_sum = df_city_group_cost_dict["p_sel"].sum()
        
        # 选父代杂交
        df_city_group_new = set()
        while len(df_city_group_new)<M:
            cur_p = random.uniform(0,total_p_sum)
            cur_pos_a = lower_bound(p_sel_sum, cur_p)
            cur_list_a = list(df_city_group_cost_dict.iloc[cur_pos_a]["route"])

            cur_p = random.uniform(0,total_p_sum)
            cur_pos_b = lower_bound(p_sel_sum, cur_p)
            cur_list_b = list(df_city_group_cost_dict.iloc[cur_pos_b]["route"])

            # 双route杂交
            hybrid_route(cur_list_a, cur_list_b, p_cro)
            
            # 两个新子代变异
            mut_route(cur_list_a, p_mut)
            mut_route(cur_list_b, p_mut)
            
            # 生成子代入set
            df_city_group_new.add(tuple(cur_list_a))
            df_city_group_new.add(tuple(cur_list_b))

        # 子代群落
        df_city_group_new = set(list(df_city_group_new)[:200])
        
        #处理子代数据，丢弃父代数据
        df_city_group_cost_dict=df_city_group_cost_dict.drop(index=df_city_group_cost_dict.index)
        for item in df_city_group_new:
            cur_city_list_cost = get_total_list_cost(list(item),df_city_map)
            df_city_group_cost_dict = df_city_group_cost_dict.append({"route":item,
                                                                      "cost":cur_city_list_cost,
                                                                      "p_sel":1.0/cur_city_list_cost},
                                                                     ignore_index=True)
        
        # 输出群落中的最优解
        loss_str_output += str(epoch) + " " + str(df_city_group_cost_dict["cost"].min())+"\n"
        if((epoch+1)%1000==0):
            min_cost_pos = list(df_city_group_cost_dict["cost"]).index(df_city_group_cost_dict["cost"].min())
            print(df_city_group_cost_dict.iloc[min_cost_pos])
            with open("./loss.txt","a+") as f:
                f.write(loss_str_output)
            f.close()
            loss_str_output = ""
# Out:
# route    (兰州, 合肥, 台湾, 西安, 广州, 南昌, 上海, 石家庄, 拉萨, 西藏, 南京, ...
# cost                                               393.219
# p_sel                                           0.00254311
# Name: 128, dtype: object
# route    (长春, 海口, 澳门, 重庆, 哈尔滨, 南京, 石家庄, 郑州, 太原, 西藏, 合肥,...
# cost                                               384.289
# p_sel                                           0.00260221
# Name: 112, dtype: object
# route    (沈阳, 太原, 兰州, 成都, 郑州, 南京, 贵阳, 天津, 石家庄, 内蒙古, 宁夏,...
# cost                                               379.856
# p_sel                                           0.00263258
# Name: 179, dtype: object
# route    (西宁, 广西, 西藏, 拉萨, 澳门, 台湾, 海口, 重庆, 南昌, 郑州, 南京, 广...
# cost                                               390.916
# p_sel                                           0.00255809
# Name: 175, dtype: object
# route    (香港, 西安, 长沙, 贵阳, 宁夏, 广州, 太原, 武汉, 济南, 石家庄, 郑州, ...
# cost                                               366.886
# p_sel                                           0.00272564
# Name: 194, dtype: object
# route    (郑州, 内蒙古, 兰州, 合肥, 长沙, 台湾, 福州, 广西, 太原, 北京, 南昌, ...
# cost                                               393.793
# p_sel                                            0.0025394
# Name: 116, dtype: object
# route    (澳门, 广州, 贵阳, 南昌, 北京, 天津, 重庆, 内蒙古, 郑州, 上海, 杭州, ...
# cost                                               369.558
# p_sel                                           0.00270593
# Name: 36, dtype: object
# route    (台湾, 济南, 南京, 上海, 海口, 贵阳, 拉萨, 澳门, 广西, 重庆, 成都, 兰...
# cost                                               370.354
# p_sel                                           0.00270012
# Name: 27, dtype: object
# route    (济南, 郑州, 澳门, 沈阳, 长春, 广州, 杭州, 海口, 长沙, 拉萨, 成都, 台...
# cost                                               403.324
# p_sel                                            0.0024794
# Name: 119, dtype: object
# route    (沈阳, 成都, 澳门, 西安, 内蒙古, 长沙, 广西, 海口, 贵阳, 香港, 郑州, ...
# cost                                               392.541
# p_sel                                            0.0025475
# Name: 43, dtype: object
# route    (南昌, 长春, 哈尔滨, 广州, 香港, 台湾, 武汉, 上海, 天津, 长沙, 拉萨, ...
# cost                                               356.883
# p_sel                                           0.00280204
# Name: 171, dtype: object
# route    (澳门, 台湾, 内蒙古, 上海, 济南, 武汉, 福州, 广州, 重庆, 哈尔滨, 南京,...
# cost                                               400.277
# p_sel                                           0.00249827
# Name: 23, dtype: object
# route    (合肥, 南京, 北京, 西安, 郑州, 成都, 济南, 武汉, 西宁, 西藏, 石家庄, ...
# cost                                               400.312
# p_sel                                           0.00249805
# Name: 173, dtype: object
# route    (福州, 北京, 上海, 新疆, 香港, 广州, 西宁, 内蒙古, 太原, 成都, 石家庄,...
# cost                                               379.555
# p_sel                                           0.00263466
# Name: 165, dtype: object
# route    (拉萨, 西宁, 哈尔滨, 武汉, 郑州, 成都, 香港, 广州, 南京, 杭州, 上海, ...
# cost                                                365.62
# p_sel                                           0.00273508
# Name: 189, dtype: object
# route    (贵阳, 成都, 太原, 内蒙古, 兰州, 武汉, 杭州, 西安, 海口, 上海, 宁夏, ...
# cost                                                381.22
# p_sel                                           0.00262316
# Name: 144, dtype: object
# route    (福州, 广州, 成都, 西藏, 西宁, 台湾, 南昌, 北京, 长沙, 西安, 重庆, 贵...
# cost                                               379.448
# p_sel                                           0.00263541
# Name: 178, dtype: object
# route    (内蒙古, 广州, 福州, 长沙, 西藏, 合肥, 成都, 新疆, 西宁, 宁夏, 重庆, ...
# cost                                               401.483
# p_sel                                           0.00249077
# Name: 167, dtype: object
# route    (海口, 重庆, 太原, 西宁, 兰州, 西藏, 成都, 新疆, 贵阳, 北京, 郑州, 福...
# cost                                               399.133
# p_sel                                           0.00250543
# Name: 45, dtype: object
# route    (杭州, 澳门, 香港, 广西, 成都, 兰州, 天津, 福州, 台湾, 哈尔滨, 西宁, ...
# cost                                               383.322
# p_sel                                           0.00260878
# Name: 46, dtype: object
# route    (天津, 上海, 台湾, 广州, 沈阳, 郑州, 哈尔滨, 北京, 石家庄, 合肥, 长沙,...
# cost                                               383.711
# p_sel                                           0.00260613
# Name: 181, dtype: object
# route    (西安, 北京, 台湾, 广州, 拉萨, 西藏, 长沙, 兰州, 沈阳, 新疆, 香港, 宁...
# cost                                               382.165
# p_sel                                           0.00261667
# Name: 56, dtype: object
# route    (广西, 杭州, 内蒙古, 郑州, 西安, 沈阳, 济南, 南昌, 澳门, 上海, 武汉, ...
# cost                                               378.874
# p_sel                                            0.0026394
# Name: 118, dtype: object
# route    (广州, 贵阳, 兰州, 澳门, 福州, 杭州, 南昌, 香港, 西宁, 石家庄, 宁夏, ...
# cost                                                378.52
# p_sel                                           0.00264187
# Name: 128, dtype: object
# route    (西安, 长春, 杭州, 合肥, 长沙, 宁夏, 西宁, 香港, 济南, 南昌, 新疆, 西...
# cost                                               361.696
# p_sel                                           0.00276475
# Name: 81, dtype: object
# route    (石家庄, 济南, 西安, 成都, 宁夏, 西宁, 拉萨, 兰州, 广州, 台湾, 南昌, ...
# cost                                               346.953
# p_sel                                           0.00288224
# Name: 175, dtype: object
# route    (武汉, 西宁, 新疆, 石家庄, 西安, 哈尔滨, 合肥, 太原, 上海, 北京, 长沙,...
# cost                                               370.086
# p_sel                                           0.00270208
# Name: 176, dtype: object
# route    (南昌, 合肥, 西宁, 香港, 澳门, 南京, 郑州, 海口, 长沙, 武汉, 西藏, 广...
# cost                                               392.802
# p_sel                                           0.00254581
# Name: 135, dtype: object
# route    (西宁, 广州, 海口, 香港, 台湾, 南昌, 上海, 哈尔滨, 福州, 武汉, 内蒙古,...
# cost                                               355.902
# p_sel                                           0.00280976
# Name: 8, dtype: object
# route    (郑州, 天津, 宁夏, 成都, 兰州, 海口, 长春, 哈尔滨, 沈阳, 南京, 西安, ...
# cost                                               388.437
# p_sel                                           0.00257442
# Name: 49, dtype: object
# route    (南京, 内蒙古, 沈阳, 福州, 郑州, 武汉, 杭州, 广州, 北京, 西藏, 天津, ...
# cost                                               387.916
# p_sel                                           0.00257788
# Name: 150, dtype: object
# route    (郑州, 太原, 杭州, 上海, 长沙, 南昌, 西藏, 广西, 新疆, 西宁, 内蒙古, ...
# cost                                               385.878
# p_sel                                           0.00259149
# Name: 8, dtype: object
# route    (郑州, 台湾, 西宁, 海口, 澳门, 西安, 成都, 广西, 南昌, 贵阳, 南京, 济...
# cost                                               372.906
# p_sel                                           0.00268164
# Name: 158, dtype: object
# route    (成都, 广西, 新疆, 兰州, 郑州, 台湾, 长沙, 西安, 重庆, 西藏, 拉萨, 贵...
# cost                                               383.954
# p_sel                                           0.00260448
# Name: 120, dtype: object
# route    (西安, 西宁, 新疆, 宁夏, 香港, 长沙, 南京, 内蒙古, 成都, 郑州, 上海, ...
# cost                                               391.993
# p_sel                                           0.00255107
# Name: 156, dtype: object
# route    (新疆, 济南, 长春, 石家庄, 重庆, 长沙, 海口, 沈阳, 武汉, 太原, 香港, ...
# cost                                               407.337
# p_sel                                           0.00245497
# Name: 45, dtype: object
# route    (重庆, 兰州, 宁夏, 哈尔滨, 内蒙古, 太原, 西宁, 北京, 石家庄, 香港, 海口...
# cost                                               395.224
# p_sel                                           0.00253021
# Name: 139, dtype: object
# route    (广州, 香港, 济南, 武汉, 郑州, 宁夏, 长春, 北京, 天津, 南昌, 重庆, 杭...
# cost                                               402.269
# p_sel                                            0.0024859
# Name: 32, dtype: object
# route    (长沙, 拉萨, 杭州, 合肥, 郑州, 济南, 南京, 南昌, 太原, 哈尔滨, 成都, ...
# cost                                               381.264
# p_sel                                           0.00262285
# Name: 10, dtype: object
# route    (南昌, 武汉, 澳门, 杭州, 拉萨, 新疆, 宁夏, 西藏, 广西, 内蒙古, 哈尔滨,...
# cost                                               400.491
# p_sel                                           0.00249693
# Name: 57, dtype: object
# route    (拉萨, 澳门, 台湾, 哈尔滨, 济南, 宁夏, 广州, 西安, 合肥, 香港, 沈阳, ...
# cost                                               411.929
# p_sel                                            0.0024276
# Name: 164, dtype: object
# route    (台湾, 杭州, 长春, 石家庄, 天津, 沈阳, 武汉, 合肥, 南昌, 宁夏, 新疆, ...
# cost                                                400.82
# p_sel                                           0.00249489
# Name: 42, dtype: object
# route    (上海, 长春, 沈阳, 北京, 广西, 南昌, 武汉, 郑州, 成都, 西安, 澳门, 哈...
# cost                                               402.558
# p_sel                                           0.00248411
# Name: 156, dtype: object
# route    (成都, 沈阳, 杭州, 西安, 武汉, 福州, 长春, 郑州, 广西, 澳门, 广州, 台...
# cost                                                360.91
# p_sel                                           0.00277077
# Name: 110, dtype: object
# route    (上海, 武汉, 济南, 太原, 石家庄, 西藏, 新疆, 西宁, 贵阳, 宁夏, 北京, ...
# cost                                               337.876
# p_sel                                           0.00295967
# Name: 161, dtype: object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-474-c451592707f6> in <module>
#      40     for item in df_city_group_new:
#      41         cur_city_list_cost = get_total_list_cost(list(item),df_city_map)
# ---> 42         df_city_group_cost_dict = df_city_group_cost_dict.append({"route":item,
#      43                                                                   "cost":cur_city_list_cost,
#      44                                                                   "p_sel":1.0/cur_city_list_cost},
#
# d:\anaconda3\envs\python38\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7740         else:
#    7741             to_concat = [self, other]
# -> 7742         return concat(
#    7743             to_concat,
#    7744             ignore_index=ignore_index,
#
# d:\anaconda3\envs\python38\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     272     ValueError: Indexes have overlapping values: ['a']
#     273     """
# --> 274     op = _Concatenator(
#     275         objs,
#     276         axis=axis,
#
# d:\anaconda3\envs\python38\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     360
#     361             # consolidate
# --> 362             obj._consolidate(inplace=True)
#     363             ndims.add(obj.ndim)
#     364
#
# d:\anaconda3\envs\python38\lib\site-packages\pandas\core\generic.py in _consolidate(self, inplace)
#    5227         inplace = validate_bool_kwarg(inplace, "inplace")
#    5228         if inplace:
# -> 5229             self._consolidate_inplace()
#    5230         else:
#    5231             f = lambda: self._mgr.consolidate()
#
# d:\anaconda3\envs\python38\lib\site-packages\pandas\core\generic.py in _consolidate_inplace(self)
#    5209             self._mgr = self._mgr.consolidate()
#    5210
# -> 5211         self._protect_consolidate(f)
#    5212
#    5213     def _consolidate(self, inplace: bool_t = False):
#
# d:\anaconda3\envs\python38\lib\site-packages\pandas\core\generic.py in _protect_consolidate(self, f)
#    5198         """
#    5199         blocks_before = len(self._mgr.blocks)
# -> 5200         result = f()
#    5201         if len(self._mgr.blocks) != blocks_before:
#    5202             self._clear_item_cache()
#
# d:\anaconda3\envs\python38\lib\site-packages\pandas\core\generic.py in f()
#    5207
#    5208         def f():
# -> 5209             self._mgr = self._mgr.consolidate()
#    5210
#    5211         self._protect_consolidate(f)
#
# d:\anaconda3\envs\python38\lib\site-packages\pandas\core\internals\managers.py in consolidate(self)
#     972         bm = type(self)(self.blocks, self.axes)
#     973         bm._is_consolidated = False
# --> 974         bm._consolidate_inplace()
#     975         return bm
#     976
#
# d:\anaconda3\envs\python38\lib\site-packages\pandas\core\internals\managers.py in _consolidate_inplace(self)
#     977     def _consolidate_inplace(self) -> None:
#     978         if not self.is_consolidated():
# --> 979             self.blocks = tuple(_consolidate(self.blocks))
#     980             self._is_consolidated = True
#     981             self._known_consolidated = True
#
# d:\anaconda3\envs\python38\lib\site-packages\pandas\core\internals\managers.py in _consolidate(blocks)
#    1897     new_blocks = []
#    1898     for (_can_consolidate, dtype), group_blocks in grouper:
# -> 1899         merged_blocks = _merge_blocks(
#    1900             list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    1901         )
#
# d:\anaconda3\envs\python38\lib\site-packages\pandas\core\internals\managers.py in _merge_blocks(blocks, dtype, can_consolidate)
#    1920         # combination of those slices is a slice, too.
#    1921         new_mgr_locs = np.concatenate([b.mgr_locs.as_array for b in blocks])
# -> 1922         new_values = np.vstack([b.values for b in blocks])
#    1923
#    1924         argsort = np.argsort(new_mgr_locs)
#
# d:\anaconda3\envs\python38\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     281     """
#     282     _warn_for_nonsequence(tup)
# --> 283     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     284
#     285
#
# KeyboardInterrupt:

# %%
df_loss = pd.DataFrame(columns = ["loss"]) #创建一个空的dataframe
with open("./loss.txt","r",encoding="utf-8") as f:
    for line in f.readlines():
        epoch,loss = line.replace("\n","").split(" ")
        df_loss = df_loss.append({"epoch":epoch,"loss":float(loss)},ignore_index=True)
f.close()

# loss变化情势
plt.clf()
plt.plot(df_loss["epoch"], df_loss["loss"], 'ro-', color='#FF0000', alpha=0.8, linewidth=1, label='loss')
plt.legend(loc="upper left")
plt.xlabel('epoch')
plt.ylabel('loss')
